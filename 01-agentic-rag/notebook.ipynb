# %%
from dotenv import load_dotenv
load_dotenv()

from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI

# %%
documents = load_faq_data()
index = build_index(documents)

openai_client = OpenAI()

# %%
assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag("How do I run Ollama locally?")
print(answer)
# Out:
# Run Ollama locally by:
#
# 1. **Installing Ollama** from https://ollama.com/download
#    - macOS: install the `.pkg`
#    - Windows: install the `.msi`
#    - Linux: run:
#    ```bash
#    curl -fsSL https://ollama.com/install.sh | sh
#    ```
#
# 2. **Starting a model** in your terminal:
# ```bash
# ollama run llama3
# ```
#
# This will download the model and open a local chat interface.
#
# 3. **Testing the local server**:
# ```bash
# curl http://localhost:11434
# ```
#
# 4. **Using it in Python**:
# ```bash
# pip install ollama
# ```
#
# ```python
# import ollama
#
# response = ollama.chat(
#     model='llama3',
#     messages=[{"role": "user", "content": your_prompt}]
# )
#
# print(response['message']['content'])
# ```

# %%
print(assistant.rag("Can I still join the course after it started?"))
# Out:
# Yes, you can still join after the course has started. If you want a certificate, make sure you submit your project while submissions are still open.
